# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.DataFrame(pd.read_excel("/content/drive/MyDrive/Load/Peak01-2019-01-10.xls", header=2))
df
# Out:
#      2019-01-09 00:00:00 Unnamed: 1  ...           합계         피크값
# 0           정보통신공학부A동 일반  AI_USER11  ...  3433.510002  196.160004
# 1           정보통신공학부A동 비상  AI_USER12  ...   339.750000   32.689999
# 2                    크린룸  CH04_10-W  ...  2446.763672  101.948486
# 3           정보통신공학부B동 일반  AI_USER15  ...    42.480000    1.770000
# 4           정보통신공학부B동 비상  AI_USER16  ...   537.359985   22.389999
# ...                  ...        ...  ...          ...         ...
# 1435                 NaN        NaN  ...          NaN         NaN
# 1436                 NaN        NaN  ...          NaN         NaN
# 1437                 NaN        NaN  ...          NaN         NaN
# 1438                 NaN        NaN  ...          NaN         NaN
# 1439                 NaN        NaN  ...          NaN         NaN
#
# [1440 rows x 70 columns]

# %%
ex=df.columns.values[0]
ex
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
import time
unixtime = time.mktime(ex.timetuple())
unixtime
# Out:
# 1577836800.0

# %%
info_location=df.iloc[:,0]
info_location
# Out:
# 0       정보통신공학부A동 일반
# 1       정보통신공학부A동 비상
# 2                크린룸
# 3       정보통신공학부B동 일반
# 4       정보통신공학부B동 비상
#             ...
# 1435             NaN
# 1436             NaN
# 1437             NaN
# 1438             NaN
# 1439             NaN
# Name: 2019-01-09 00:00:00, Length: 1440, dtype: object

# %%
df_data

# %%
df_data=df[0:29].iloc[:,2:26]
df_data.index=info_location[0:29]

# %%
import os 
import tqdm
for dirname, _, filenames in os.walk('/content/drive/MyDrive/load_1'):
  for filename in filenames[0:10]: 
    str=os.path.join(dirname, filename)
    df = pd.DataFrame(pd.read_excel(str, header=2))
    df_data=df[0:29].iloc[:,2:26]
    df_data.index=info_location[0:29]

# %%
df_data.iloc[:,0]
# Out:
# 0     125.599998
# 1      12.790000
# 2     101.948486
# 3       1.770000
# 4      22.389999
# 5      58.446552
# 6       3.813628
# 7     341.200012
# 8      40.150002
# 9     130.537827
# 10      9.544204
# 11    120.070000
# 12     24.520000
# 13     77.380119
# 14      9.008092
# 15    362.779999
# 16     22.200001
# 17    407.279999
# 18     42.869999
# 19     19.813713
# 20     76.158455
# 21     99.691277
# 22     46.008076
# 23     48.830002
# 24     19.950001
# 25     83.365608
# 26      4.602067
# 27     18.940001
# 28      0.000000
# Name: 00:00, dtype: float64

# %%
peak1_EE1=[] #전기전자컴퓨터 1동 array
for dirname, _, filenames in os.walk('/content/drive/MyDrive/load_1'):#load_1은 파일 peak1의 데이터
  for filename in filenames: 
    str=os.path.join(dirname, filename)
    df = pd.DataFrame(pd.read_excel(str, header=2))
    df_data=df[0:29].iloc[:,2:26]
    peak1_EE1.append(df_data.iloc[:,0])
peak1_EE1_n=np.asarray(peak1_EE1).reshape(-1) #colab 기준 3분~4분 정도 걸림

# %%
np.asarray(peak1_EE1).reshape(-1)
# Out:
# array([ 46.88999939,  -0.87      , 101.94848633,   1.76999998,
#         22.38999939,  58.44655228,   3.81362844, 279.80999756,
#         33.27999878, 110.74601746,   7.78530598,  65.05000305,
#          5.94999981,  63.15901184,   6.25685978, 309.73001099,
#         15.68999958, 346.61999512,  32.72000122,  19.14827347,
#         76.1584549 ,  95.27952576,  35.23493958,  40.72999954,
#         18.45000076,  58.40821075,   3.85290694,   8.26000023,
#          0.        ,  63.27000046,  -2.57999992, 101.94848633,
#          1.76999998,  22.38999939,  58.44655228,   3.81362844,
#        282.57000732,  27.20000076, 106.12295532,   7.69087029,
#         76.94000244,   6.55999994,  65.13902283,   6.82722759,
#        345.91000366,  15.51000023, 367.39001465,  31.65999985,
#         18.6604805 ,  76.1584549 ,  83.84153748,  34.38528061,
#         36.63000107,  17.98999977,  55.92321014,   3.89143944,
#         10.35000038,   0.        ,  75.63999939,   0.94999999,
# ...

# %%
new_series=pd.Series(peak1_EE1_n)

# %%
new_series
# Out:
# 0        46.889999
# 1        -0.870000
# 2       101.948486
# 3         1.770000
# 4        22.389999
#            ...
# 9826     60.810001
# 9827     95.486473
# 9828      6.590966
# 9829     22.940001
# 9830      1.055364
# Length: 9831, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(new_series, model='additive')
plt.rcParams['figure.figsize'] = [12, 8]

result.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-a79601fa4016> in <module>()
#       1 from statsmodels.tsa.seasonal import seasonal_decompose
#       2
# ----> 3 result = seasonal_decompose(new_series, model='additive')
#       4 plt.rcParams['figure.figsize'] = [12, 8]
#       5
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     106     """
#     107     if freq is None:
# --> 108         _pandas_wrapper, pfreq = _maybe_get_pandas_wrapper_freq(x)
#     109     else:
#     110         _pandas_wrapper = _maybe_get_pandas_wrapper(x)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/filters/_utils.py in _maybe_get_pandas_wrapper_freq(X, trim)
#      46         index = X.index
#      47         func = _get_pandas_wrapper(X, trim)
# ...
